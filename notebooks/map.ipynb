# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import geodatasets

file_path = "../data/raw/HDI.csv"
df = pd.read_csv(file_path,usecols = ['ISO3','Country','Continent','HDI Rank (2021)','Labour force participation rate, female (% ages 15 and older) (2017)','Labour force participation rate, female (% ages 15 and older) (2018)','Labour force participation rate, female (% ages 15 and older) (2019)','Labour force participation rate, female (% ages 15 and older) (2020)','Labour force participation rate, female (% ages 15 and older) (2021)'])
display(df)
# Out:
#     ISO3               Country Continent  HDI Rank (2021)  \
# 0    AFG           Afghanistan      Asia            180.0
# 1    AGO                Angola    Africa            148.0
# 2    ALB               Albania    Europe             67.0
# 3    AND               Andorra    Europe             40.0
# 4    ARE  United Arab Emirates      Asia             26.0
# ..   ...                   ...       ...              ...
# 190  WSM                 Samoa   Oceania            111.0
# 191  YEM                 Yemen      Asia            183.0
# 192  ZAF          South Africa    Africa            109.0
# 193  ZMB                Zambia    Africa            154.0
# 194  ZWE              Zimbabwe    Africa            146.0
#
#      Labour force participation rate, female (% ages 15 and older) (2017)  \
# 0                                               20.887
# 1                                               74.912
# 2                                               49.510
# ...

# %%
world = gpd.read_file(geodatasets.get_path('naturalearth land'))
world
#geodatasets.data.naturalearth.land
#gpd.datasets.get_path('natural_earth_lowres')
#world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# Out:
#     featurecla  scalerank  min_zoom  \
# 0         Land          1       1.0
# 1         Land          1       1.0
# 2         Land          1       0.0
# 3         Land          1       1.0
# 4         Land          1       1.0
# ..         ...        ...       ...
# 122       Land          1       1.0
# 123       Land          0       0.0
# 124       Land          0       0.0
# 125       Land          0       0.0
# 126       Land          0       0.0
#
#                                               geometry
# 0    POLYGON ((-59.57209 -80.04018, -59.86585 -80.5...
# 1    POLYGON ((-159.20818 -79.49706, -161.1276 -79....
# 2    POLYGON ((-45.15476 -78.04707, -43.92083 -78.4...
# 3    POLYGON ((-121.21151 -73.50099, -119.91885 -73...
# 4    POLYGON ((-125.55957 -73.48135, -124.03188 -73...
# ..                                                 ...
# 122  POLYGON ((51.13619 80.54728, 49.79368 80.41543...
# 123  POLYGON ((99.93976 78.88094, 97.75794 78.7562,...
# ...

# %%
world = gpd.read_file(geodatasets.get_path('naturalearth land'))
world
world = world.merge(df, how='left', left_on='Country', right_on='Country')

# Step 4: Plot the map
# Normalize the HDI values for color mapping
norm = mcolors.Normalize(vmin=world['HDI Rank (2021)'].min(), vmax=world['HDI Rank (2021)'].max())

# Create a color map (choose a suitable colormap)
cmap = plt.cm.viridis  # A colormap ranging from light to dark

# Plot the map
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
world.boundary.plot(ax=ax, linewidth=1)  # Plot boundaries
world.plot(column='HDI Rank (2021)', ax=ax, cmap=cmap, norm=norm, legend=True, 
           legend_kwds={'label': "Human Development Index (HDI)", 'orientation': "horizontal"})

# Show the map
plt.title('World Map of Human Development Index (HDI)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6648\2379293040.py in ?()
# ----> 3 world = gpd.read_file(geodatasets.get_path('naturalearth land'))
#       4 world
#       5 world = world.merge(df, how='left', left_on='Country', right_on='Country')
#       6
#
# ~\Ironhack\Week_3\FirstProject\venv\lib\site-packages\pandas\core\frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10828         validate: MergeValidate | None = None,
#   10829     ) -> DataFrame:
#   10830         from pandas.core.reshape.merge import merge
#   10831
# > 10832         return merge(
#   10833             self,
#   10834             right,
#   10835             how=how,
#
# ...
